# %% [markdown]
# # Realiza la mezcla de varias señales de audio

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
x1, sr1 = librosa.load('data/1.wav', mono=True)
ipd.Audio(x1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x2, sr2 = librosa.load('data/2.wav', mono=True)
ipd.Audio(x2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x3, sr3 = librosa.load('data/3.wav', mono=True)
ipd.Audio(x3, rate=sr3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x4, sr4 = librosa.load('data/4.wav', mono=True)
ipd.Audio(x4, rate=sr4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
min(len(x1), len(x2), len(x3), len(x4))
# Out:
# 39730

# %%
x1=x1[:39730]
x2=x2[:39730]
x3=x3[:39730]
x4=x4[:39730]

# %%
mix=(x1+x2+x3+x4)/4

sr_mix=int((sr1+sr2+sr3+sr4)/4)

librosa.display.waveplot(mix, sr=sr_mix)



ipd.Audio(mix, rate=sr_mix)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.output.write_wav('data/mix.wav', mix, sr_mix)
